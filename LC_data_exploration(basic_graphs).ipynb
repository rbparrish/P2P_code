# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# # Data Exploration and Preprocessing - LC Data
#
# -----

# %% [markdown]
# ### Data Exploration

# %%
# !ls ../Raw_Data/LendingClub/
# Out:
# ~$LCDataDictionary.xlsx  LoanStats3a.csv      LoanStats3a_head.csv
# LCDataDictionary.xlsx	 LoanStats3a.csv.zip  LoanStats3b.csv.zip

# %%
import open_subset as op
LCdata = op.open_and_process("../Raw_Data/LendingClub/LoanStats3a.csv","feature_subset")

# %%
LCdata
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42538 entries, 0 to 42537
# Data columns (total 15 columns):
# title              42524  non-null values
# desc               29243  non-null values
# is_inc_v           42535  non-null values
# loan_amnt          42535  non-null values
# term               42535  non-null values
# int_rate           42535  non-null values
# grade              42535  non-null values
# home_ownership     42535  non-null values
# fico_range_high    42535  non-null values
# fico_range_low     42535  non-null values
# dti                42535  non-null values
# purpose            42535  non-null values
# annual_inc         42531  non-null values
# emp_length         42535  non-null values
# loan_status        42535  non-null values
# dtypes: float64(5), object(10)

# %% [markdown]
# ## Check datatypes for all features

# %%
import exploration as ex
ex.check_types(LCdata)
# Out:
# [('title', {str, float}),
#  ('desc', {str, float}),
#  ('is_inc_v', {bool, float}),
#  ('loan_amnt', {numpy.float64}),
#  ('term', {str, float}),
#  ('int_rate', {str, float}),
#  ('grade', {str, float}),
#  ('home_ownership', {str, float}),
#  ('fico_range_high', {numpy.float64}),
#  ('fico_range_low', {numpy.float64}),
#  ('dti', {numpy.float64}),
#  ('purpose', {str, float}),
#  ('annual_inc', {numpy.float64}),
#  ('emp_length', {str, float}),
#  ('loan_status', {str, float})]

# %%
import open_subset as op
LCdata_t = op.open_and_process("../Raw_Data/LendingClub/LoanStats3a.csv","transform")
ex.check_types(LCdata_t)
# Out:
# [('title', {numpy.int64}),
#  ('desc', {numpy.int64}),
#  ('is_inc_v', {bool}),
#  ('loan_amnt', {numpy.float64}),
#  ('term', {numpy.float64}),
#  ('int_rate', {numpy.float64}),
#  ('grade', {str}),
#  ('home_ownership', {str}),
#  ('fico_range_high', {numpy.float64}),
#  ('fico_range_low', {numpy.float64}),
#  ('dti', {numpy.float64}),
#  ('purpose', {str}),
#  ('annual_inc', {numpy.float64}),
#  ('emp_length', {str}),
#  ('loan_status', {str})]

# %% [markdown]
# ## Data Exploration

# %%
LCdata_t['title'].hist(bins=20)
# rule in place to not have titles greater than 40?  Higher seems suspect (or older)

# %%
LCdata_t[LCdata_t['desc'] <= 1500]['desc'].hist(bins=20)

# %%
LCdata_t.plot(x='title', y='desc', style='o', alpha=0.3)
# seems like maybe a rule was put in place for length < 40 chars?

# %%
LCdata_t['annual_inc'].hist(bins=20)
# need to get rid of outliers

# %%
LCdata_t[LCdata_t['annual_inc'] <= 200000]['annual_inc'].hist(bins=20)

# %%
LCdata_t['is_inc_v'].value_counts().plot(kind='bar')

# %%
LCdata_t[LCdata_t['is_inc_v']==True][LCdata_t['annual_inc']<=200000]['annual_inc'].hist(bins=20)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.py:2021: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)

# %%
LCdata_t[LCdata_t['is_inc_v']==False][LCdata_t['annual_inc']<=200000]['annual_inc'].hist(bins=20)

# %%
test = LCdata_t['emp_length']
test.value_counts().plot(kind='bar')

# %%
LCdata_t['home_ownership'].value_counts().plot(kind='bar')

# %%
LCdata_t['fico_range_low'].plot(kind='kde')
LCdata_t['fico_range_high'].plot(kind='kde')

# %%
LCdata_t['dti'].plot(kind='kde')

# %%
LCdata_t['purpose'].value_counts().plot(kind='bar')

# %%
LCdata_t['loan_amnt'].hist(bins=20)

# %%
LCdata_t['term'].hist(bins=20)

# %%
LCdata_t['int_rate'].hist(bins=20)

# %%
LCdata_t['grade'].value_counts().plot(kind='bar')

# %%
LCdata_t['loan_status'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Changes to make from data exploration
#
# #### Tranforming variable to predict
#
# - To do:
#     - remove all "Does not meet the credit policy"; unsure of consequences of this data
#     - group Default into Charged Off category
#     - remove all Late and Current loans (current loans may still default, late may still be paid)
#     - don't worry about consequence of Fully Paid early account on this go
#
# - questions
#     - What is the "average" cost of a Charged Off/Defaulted note? (70%?  100%?) > START WITH 90% loss assumption
#
#
# #### Transforming feature variables
#
# - To do:
#     - remove all with titles > len(40)
#     - remove all with incomes > 200000
#         - not only is there very few, it doesn't make sense for these people to be searching for loans
#     - transform year working into continuous ( '< 1' to 0.5; 'n/a' to 0; '10+' to 10 )
#     - categorical variables (do "dumb tranformation")
#         - home_ownership (also, remove 'other' & 'none', v. small groups)
#         - purpose
#     - change is_inc_v(erified) to boolean T/F
#
#
# - Done before this analysis:
#     - title changed to title length
#     - desc change to description length
#     - purpose: NaN changed to 'not_given'
#     - all NaNs were dropped
#     - 'term' and 'int_rate' strings transformed into floats (misc. chars removed)
#     - NO NORMALIZATION COMPLETED YET
#
#
# - Possible future transformations:
#     - make a feature that is purely True/False for whether somewone wrote a description at all
#
#
# - Other possible future changes
#     - include other features

# %% [markdown]
# ## Notes related to completing feature transforms above

# %%
LCdata_t2 = LCdata_t[LCdata_t['title'] <= 40]

# %%
bf = LCdata_t['title']
af = LCdata_t2['title']
LCdata_t.boxplot(column='title')
LCdata_t2.boxplot(column='title')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xb568a10>],
#  'caps': [<matplotlib.lines.Line2D at 0xb561d50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xb56c690>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0xb56c090>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xb561490>,
#   <matplotlib.lines.Line2D at 0xb561710>]}

# %%
LCdata_t2 = LCdata_t2[LCdata_t2['annual_inc'] <= 200000]
LCdata_t2.boxplot(column='annual_inc')
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xbbaf390>],
#  'caps': [<matplotlib.lines.Line2D at 0xbbad6d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xbbb3050>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0xbbaf9d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xbba9d50>,
#   <matplotlib.lines.Line2D at 0xbba9fd0>]}

# %%
#based on graph above going to change limit from 200000 to 150000
LCdata_t2['annual_inc'].describe()
# Out:
# count     41420.000000
# mean      64632.861803
# std       33829.216394
# min        1896.000000
# 25%       40000.000000
# 50%       57996.000000
# 75%       80000.000000
# max      200000.000000
# dtype: float64

# %%
from parsers import parse_employment_years
tester = LCdata_t2['emp_length'].tail(n=41)
tester.apply(parse_employment_years)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-dd57c8e06254> in <module>()
#       1 from parsers import parse_employment_years
#       2 tester = LCdata_t2['emp_length'].tail(n=41)
# ----> 3 tester.apply(parse_employment_years)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2534             values = lib.map_infer(values, lib.Timestamp)
#    2535
# -> 2536         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2537         if isinstance(mapped[0], Series):
#    2538             from pandas.core.frame import DataFrame
#
# /usr/local/lib/python2.7/dist-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:42840)()
#
# /vagrant/Project/P2P/P2P_code/parsers.pyc in parse_employment_years(x)
#      36             return float(0.5)
#      37         elif sp[0] == '10+':
# ...

# %%
reload(op)
# Out:
# <module 'open_subset' from 'open_subset.py'>

# %%
LCdata_t2['emp_length'] = LCdata_t2['emp_length'].apply(op.parse_employment_years)
LCdata_t2['emp_length'].head(n=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-0d230be48eb7> in <module>()
# ----> 1 LCdata_t2['emp_length'] = LCdata_t2['emp_length'].apply(op.parse_employment_years)
#       2 LCdata_t2['emp_length'].head(n=20)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2534             values = lib.map_infer(values, lib.Timestamp)
#    2535
# -> 2536         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2537         if isinstance(mapped[0], Series):
#    2538             from pandas.core.frame import DataFrame
#
# /usr/local/lib/python2.7/dist-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:42840)()
#
# /vagrant/Project/P2P/P2P_code/parsers.pyc in parse_employment_years(x)
#      36         elif sp[0] == '10+':
#      37             return float(10)
# ...

# %%
LCdata_t2['emp_length'].value_counts()
# Out:
# 10+ years    9082
# < 1 year     4935
# 2 years      4605
# 3 years      4248
# 4 years      3572
# 1 year       3509
# 5 years      3369
# 6 years      2315
# 7 years      1834
# 8 years      1544
# 9 years      1310
# n/a          1097
# dtype: int64
