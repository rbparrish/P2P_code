# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
import open_subset as op
import parsers as pa
import exploration as ex
import model

# %%
import analysis

# %%
reload(analysis)
vis = analysis.Visualize()
# Out:
# ready for .age_last_payment(type)

# %%
months = ['2010-01','2010-02','2010-03','2010-04','2010-05','2010-06']
vis.age_by_month_defaulted(months)

# %%
months = ['2011-01','2011-02','2011-03','2011-04','2011-05','2011-06']
vis.age_by_month_defaulted(months)

# %%
months = ['2012-01','2012-02','2012-03','2012-04','2012-05','2012-06']
vis.age_by_month_defaulted(months)

# %%
months = ['2013-01','2013-02','2013-03','2013-04','2013-05','2013-06']
vis.age_by_month_defaulted(months)
# "seems" as though the relative defaults in months 3-12 have gone up compared to defaults in 21-30

# %%
months = ['2011-01','2011-02','2011-03','2011-04','2011-05','2011-06']
vis.age_based_on_start_month(months)

# %%
months = ['2012-01','2012-02','2012-03','2012-04','2012-05','2012-06']
vis.age_based_on_start_month(months)

# %%
months = ['2013-01']
vis.age_based_on_start_month(months)

# %%
len(vis.db[vis.db['yy-mm_start_date'].isin(['2007-06'])])
# Out:
# 41

# %%
# default rate based on age

# %%
# just assume they are all "in the same macro-economic space" (to start out with)

# %%
# provide the justification
# "beyond the scope" is trying to account for time
# later time periods provide information on previous
# what is the total number of starts in month X?
